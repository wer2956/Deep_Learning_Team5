# %%
import cv2
from PIL import Image
import os
face_cascade = cv2.CascadeClassifier('haar cascade files\haarcascade_frontalface_alt.xml')
eye_casecade = cv2.CascadeClassifier('haar cascade files\haarcascade_eye.xml')

origin_dir = os.path.join('images/normal_1_images/original')
cropped_dir = os.path.join('images/normal_1_images/cropped/')
image_list = os.listdir(origin_dir)
for filename in image_list:
    print(filename)
    imagename = os.path.join(origin_dir,filename)
    newimagename = os.path.join(cropped_dir,filename)
    img = cv2.imread(imagename)
    print(imagename)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3,5)
    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)
        cropped = img[y:y + h, x:x + w]
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_casecade.detectMultiScale(roi_gray)
        lx = 1000
        ly = 1000
        lw = 0
        lh = 0
        rx = 0
        ry = 0
        rw = 0
        rh = 0
        for (ex, ey, ew, eh) in eyes:
            if(ew > 20) :
                #cv2.rectangle(roi_color, (ex,ey), (ex+ew, ey+eh),(0,255,0),2)
                if(ex< lx):
                    lx = ex
                    ly = ey
                    lw = ew
                    lh = eh

                if(ex > rx):
                    rx = ex
                    ry = ey
                    rw = ew
                    rh = eh
                #print(ex, ey, ew, eh)
            width = rx+rw-lx
            if(lh > rh) :
                height = lh
            else:
                height = rh
            if(ly > ry) :
                fy = ry
            else:
                fy = ly
            #print(lx, ly+lh, rx+rw, ry+rh+rw)
            #print(width, height, fy)
            area = (lx, fy, width, height)
    print(fy, lx)
    print(width, height)
    cropped2 = img[70+y:70 + 55+y, 50 - int(150/15)+x:50 + 150 + int(150/15)+x]
    cv2.imwrite(newimagename, cropped2)
#cv2.imshow('Image view', cropped2)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# normal_1_images0.jpg
# images/normal_1_images/original\normal_1_images0.jpg
# 68 54
# 147 54
# normal_1_images1.jpg
# images/normal_1_images/original\normal_1_images1.jpg
# 60 51
# 147 56
# normal_1_images10.jpg
# images/normal_1_images/original\normal_1_images10.jpg
# 65 50
# 148 61
# normal_1_images100.jpg
# images/normal_1_images/original\normal_1_images100.jpg
# 65 36
# 153 53
# normal_1_images101.jpg
# images/normal_1_images/original\normal_1_images101.jpg
# 62 35
# 153 52
# normal_1_images102.jpg
# images/normal_1_images/original\normal_1_images102.jpg
# 58 39
# 153 55
# normal_1_images103.jpg
# images/normal_1_images/original\normal_1_images103.jpg
# 64 34
# 155 53
# normal_1_images104.jpg
# images/normal_1_images/original\normal_1_images104.jpg
# 59 36
# 151 55
# normal_1_images105.jpg
# images/normal_1_images/original\normal_1_images105.jpg
# 60 35
# 155 56
# normal_1_images106.jpg
# images/normal_1_images/original\normal_1_images106.jpg
# 58 39
# 153 55
# ...
